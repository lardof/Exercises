# %%
import matplotlib.pyplot as plt

# %%
a = [15,25,35,65]
b = [100,200,300,400]
plt.plot(a,b,"r")  #red r ile ifade edilbeilir green g ile ifade edilebilir

# %%
import numpy as np

# %%
dizi1 = np.linspace(10,100,11) #linspace 10 dan 100'e kadar 11 tane deger alir
dizi2 = dizi1 ** 2

plt.plot(dizi1,dizi2,"g--")

# %%
plt.plot(dizi1,dizi2,"g*-")

# %% [markdown]
# # figure kaydetme

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dizi1 = [1,2,3,4,5]
dizi2 = [2,4,6,8,10]

fig1 = plt.figure()

plt.plot(dizi1, dizi2, "g*-")

fig1.savefig("figure1.png", dpi=200)
